# %% [markdown]
# <a href="https://colab.research.google.com/github/qianxi5/50.001_budget_tracker_app/blob/main/extended_boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('drive/My Drive/IR/Info Retrieval Group Project/recipes_w_search_terms.csv', nrows=5000)
df.shape
# Out:
# (5000, 10)

# %%
df.head()
# Out:
#        id                                   name  \
# 0   96313            Grilled Garlic Cheese Grits
# 1  232037  Simple Shrimp and Andouille Jambalaya
# 2   41090             black-and-white bean salad
# 3   60656             Crock Pot Italian Zucchini
# 4  232047          Beef Stew With Dried Cherries
#
#                                          description  \
# 0  We love grits, this is another good way to ser...
# 1  Simple, easy and very tasty for when you are i...
# 2                                                NaN
# 3  This is a good recipe for weight watchers. It ...
# 4  This is a fabulous stew that came from one of ...
#
#                                          ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1  ['onion', 'red bell pepper', 'garlic cloves', ...
# 2  ['white beans', 'canned black beans', 'tomatoe...
# 3  ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4  ['beef stew meat', 'flour', 'salt', 'allspice'...
#
#                                  ingredients_raw_str serving_size  servings  \
# 0  ["4   cups    water","1   cup   uncooked old f...    1 (155 g)         8
# 1  ["1   medium    onion, chopped coarse ","1   m...    1 (366 g)         4
# 2  ["1   cup   canned white beans, rinsed and dra...    1 (807 g)         1
# 3  ["2       zucchini, sliced ","2   small    yel...    1 (244 g)         4
# 4  ["3   lbs    beef stew meat","3   tablespoons ...    1 (358 g)         8
#
#                                                steps  \
# 0  ['I a sauce pan, bring water to a boil; slowly...
# 1  ['In a food processor, pulse the onion, red pe...
# 2  ['In a large bowl, combine beans, tomato, onio...
# 3  ['Put all ingredients in the crock pot and coo...
# 4  ['Preheat oven to 350°F.', "Cut beef into 1 in...
#
#                                                 tags  \
# 0  ['time-to-make', 'course', 'main-ingredient', ...
# 1  ['60-minutes-or-less', 'time-to-make', 'course...
# 2  ['15-minutes-or-less', 'time-to-make', 'course...
# 3  ['weeknight', 'time-to-make', 'course', 'main-...
# 4  ['time-to-make', 'course', 'main-ingredient', ...
#
#                                         search_terms
# 0  {'diabetic', 'low-calorie', 'vegetarian', 'low...
# 1                               {'dinner', 'shrimp'}
# 2  {'vegetarian', 'salad', 'side', 'dinner', 'veg...
# 3                  {'side', 'vegetarian', 'italian'}
# 4                                         {'dinner'}

# %%
def function(ini_list):
  new_cell = ini_list.strip('][').split(', ')
  for item in new_cell:
    item = item.replace("'","")
  return new_cell

df['ingredients'] = df['ingredients'].apply(function)
df2 = df[['id', 'name','ingredients','steps']]
df2.head()
# Out:
#        id                                   name  \
# 0   96313            Grilled Garlic Cheese Grits
# 1  232037  Simple Shrimp and Andouille Jambalaya
# 2   41090             black-and-white bean salad
# 3   60656             Crock Pot Italian Zucchini
# 4  232047          Beef Stew With Dried Cherries
#
#                                          ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1  ['onion', 'red bell pepper', 'garlic cloves', ...
# 2  ['white beans', 'canned black beans', 'tomatoe...
# 3  ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4  ['beef stew meat', 'flour', 'salt', 'allspice'...
#
#                                                steps
# 0  ['I a sauce pan, bring water to a boil; slowly...
# 1  ['In a food processor, pulse the onion, red pe...
# 2  ['In a large bowl, combine beans, tomato, onio...
# 3  ['Put all ingredients in the crock pot and coo...
# 4  ['Preheat oven to 350°F.', "Cut beef into 1 in...

# %% [markdown]
# make a search engine for ingredients which will show the name of dish and steps as the output

# %%
ingredients = df2['ingredients']
ingredients.head()
# Out:
# 0    ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1    ['onion', 'red bell pepper', 'garlic cloves', ...
# 2    ['white beans', 'canned black beans', 'tomatoe...
# 3    ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4    ['beef stew meat', 'flour', 'salt', 'allspice'...
# Name: ingredients, dtype: object

# %%
# Finding the set of unique ingredients from all dishes
all_ingredients = []

# %%
import nltk
from nltk.tokenize import word_tokenize
import re
import sys
import time
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
start = time.time()

# %%
from collections import defaultdict
def find_words_freq(words):
  word_dict = defaultdict(float) # key: word, value: word frequency in the doc
  for word in words:
    word_dict[word] += 1
  return word_dict
        
def remove_special_characters(text):
    regex = re.compile('[^a-zA-Z0-9\s]')
    text_returned = re.sub(regex,'',text)
    return text_returned

# %%
class Node:
    def __init__(self ,docId, freq = None):
        self.freq = freq
        self.doc = docId
        self.nextval = None
    
class SlinkedList:
    def __init__(self ,head = None):
        self.head = head

# %%
dictionary = {} #key: ingredient, value: [posting list]
# unique_words_all = set()
dict_global = {}
for idx, ingre_lst in enumerate(ingredients):
  words = []
  for ingre in ingre_lst:
    ingre = ingre[1:-1] # remove apostrophe
    ingre = remove_special_characters(ingre).lower()
    for word in ingre.split():
      words.append(word)
  dict_global.update(find_words_freq(words))
    # unique_words_all.add(ingre)
    # if ingre not in dictionary: dictionary[ingre] = [idx]
    # else:
    #   if dictionary[ingre][-1] != idx: dictionary[ingre].append(idx)

unique_words_all = set(dict_global.keys())
print(len(unique_words_all))
print(unique_words_all)
# Out:
# 1996
# {'rum', 'marshmallow', 'chambord', 'sweetcorn', 'nam', 'chianti', 'shoe', 'grouper', 'shortcake', 'pepperoni', 'cellophane', 'tuna', 'szechwan', 'pecorino', 'sardines', 'beef', 'tiny', 'accent', 'smart', 'wafers', 'shimeji', 'zucchini', 'crabmeat', 'sandwich', 'chunk', 'vegemite', 'fajitasize', 'jamaican', 'spareribs', 'pita', 'glazed', 'tots', 'collard', 'machine', 'vodka', 'fig', 'relish', 'rotisseriecooked', 'half', 'curlyleaf', 'graham', 'dijonnaise', 'starter', 'leaves', 'scrambler', 'polish', 'brand', 'cayenne', 'philadelphia', 'twine', 'dr', 'pumpkin', 'steel', 'halibut', 'stout', 'grease', 'cow', 'reducedcalorie', 'caramelswirl', 'mexicanstyle', 'lard', 'dessert', 'toffee', 'fullcream', 'tarts', 'coleman27s', 'cornish', 'limoncello', 'diet', 'crescent', 'secrets', 'season', 'chachere27
pea', 'soy', 'currants', '9grain', 'old', 'pickled', 'long', 'chinese', 'rye', 'mini', 'cognac', 'praline', 'porcini', 'barrel', 'bun', 'fudge', 'pickle', 'honeyroasted', 'pantry26reg3b', 'stirfry', 'shrimp', 'bavarian', 'swirl', 'shreddies', 'tarragon', 'spaghetti', 'mandarin', 'lan', '151', 'frying', 'kernel', 'nuts', 'mutton', 'hoagie', 'za27atar', 'orzo', 'oldfashioned', 'pecan', 'firm', 'heavy', 'cashew', 'powder', 'short', 'cake', 'tips', 'liquor', 'spaghettini', 'tenderloin', 'gingerroot', 'cubes', 'cheesefilled', 'leather', 'yolks', 'extra', 'cucumber', 'pears', ' ...

# %%
all_ingredients = []
df = {}
idf = {}

for idx, ingre_list in enumerate(ingredients):
  weight_vector = []
  freq_in_doc = {}
  for ingre in ingre_list:
    term = ingre[1:-1].lower() # remove apostrophe
    all_ingredients.append(term)
    term_count = freq_in_doc.get(term, 0) + 1
    freq_in_doc[term] = term_count
  for term in set(ingre_list):
    term =  ingre[1:-1].lower() # remove apostrophe
    df_count = df.get(term,0)+1
    df[term] = df_count
corpus_size  = len(all_ingredients)
import math
for term, freq in df.items():
  idf[term] = round(math.log((corpus_size) / (freq)),2)


uniqe_all_ingredients = set(all_ingredients)
print(idf)
print(len(idf))
print(len(all_ingredients))
print(len(uniqe_all_ingredients))
# Out:
# {'olive oil': 4.46, 'fresh parsley': 4.77, 'salt and pepper': 3.57, 'mushroom': 7.71, 'cayenne pepper': 5.21, 'potato chips': 6.95, 'extra virgin olive oil': 5.66, 'parsley': 4.8, 'onion powder': 7.0, 'decorator sugar': 7.87, 'semi-sweet chocolate chips': 5.93, 'fresh ground black pepper': 4.81, 'strawberry': 7.0, 'lemon%2c juice of': 7.39, 'vegetables': 8.46, 'butter': 3.93, 'water': 3.87, 'buttered bread crumb': 8.05, 'liquid smoke': 6.77, 'clove': 7.23, 'pie crusts': 7.17, 'pasta sauce': 7.58, 'brown sugar': 5.77, 'salt': 3.62, 'milk': 4.88, 'parmesan cheese': 3.74, 'icing sugar': 6.07, 'rice': 6.4, 'tomatoes': 5.97, 'red food coloring': 7.29, 'crema': 8.12, 'pecans': 4.75, 'sweetened cocoa powder': 8.68, 'pineapple juice': 7.04, 'shortening': 6.87, 'cooking oil': 6.47, 'cheddar cheese': 4.66, 'black pepper': 4.67, 'flour': 5.33, 'salt %26 pepper': 5.73, 'cooked shrimp': 8.68, 'crescent roll dough': 8.81, 'almond extract': 7.0, 'lemon juice': 5.18, 'provolone cheese': 7.26, 'ground allspice': 8.68, 'vanilla essence': 8.05, 'pepper': 3.66, 'bay leaf': 6.5, 'chives': 5.85, 'nuts': 4.94, 'seasoning': 7.99, 'macaroni noodles': 8.68, 'cider vinegar': 6.93, 'green cardamom pods': 9.15, 'allspice': 8.81, 'muenster cheese': 7.2, 'shredded coconut': 7.04, 'whipped cream': 5.85, 'reynolds wrap foil': 7.58, 'pistachios': 7.02, 'cinnamon-sugar mixture': 7.76, 
# 1345
# 46994
# 4392

# %%
weight_vectors = {}
for idx, ingre_list in enumerate(ingredients):
  weight_vector = {}
  freq_in_doc = {}
  for ingre in ingre_list:
    term = ingre[1:-1].lower() # remove apostrophe
    term_count = freq_in_doc.get(term, 0) + 1
    weight = term_count * (idf.get(term, 0)/max(idf.values()))
    weight_vector[term] = weight
  weight_vectors[idx] = weight_vector

print(weight_vectors)
# Out:
# {0: {'water': 0.3846918489065606, 'grits': 0.0, 'salt': 0.35984095427435386, 'cheddar cheese': 0.46322067594433397, 'garlic': 0.595427435387674, 'olive oil': 0.4433399602385686}, 1: {'onion': 0.5785288270377733, 'red bell pepper': 0.6868787276341948, 'garlic cloves': 0.5805168986083499, 'large shrimp': 0.7713717693836978, 'salt': 0.35984095427435386, 'hot pepper sauce': 0.5994035785288271, 'vegetable oil': 0.5546719681908548, 'andouille sausage': 0.0, 'long grain rice': 0.0, 'bay leaves': 0.7415506958250496, 'diced tomatoes': 0.6978131212723657, 'clam juice': 0.0, 'fresh parsley': 0.4741550695825049}, 2: {'white beans': 0.0, 'canned black beans': 0.0, 'tomatoes': 0.5934393638170974, 'onion': 0.5785288270377733, 'celery': 0.7186878727634195, 'white wine vinegar': 0.0, 'italian parsley': 0.7664015904572564, 'table salt': 0.7495029821073559, 'black pepper': 0.46421471172962225, 'olive oil': 0.4433399602385686}, 3: {'zucchini': 0.6640159045725645, 'yellow squash': 0.0, 'diced tomatoes': 0.6978131212723657, 'onion': 0.5785288270377733, 'garlic': 0.595427435387674, 'green bell pepper': 0.7186878727634195, 'italian seasoning': 0.6888667992047713, 'water': 0.3846918489065606, 'salt and pepper': 0.3548707753479125}, 4: {'beef stew meat': 0.0, 'flour': 0.529821073558648, 'salt': 0.35984095427435386, 'allspice': 0.8757455268389662, 'cinnamon': 0.49204771371769385, 'black pepper': 0.46421471172962225, 'vegetable oil': 0.5546719681908548, 'onions': 0.6312127236580516, 'dried sour cherries': 0.0, 'sugar': 0.45228628230616297, 'water': 0.3846918489065606, 'dry red wine': 0.0, 'beef stock': 0.794234592445328, 'mushroom': 0.7664015904572564}, 5: {'slivered almonds': 0.7157057654075547, 'cider vinegar': 0.6888667992047713, 'sugar': 0.45228628230616297, 'salt': 0.35984095427435386, 'ground cumin': 0.676938369781312, 'ground coriander': 0.0, 'cayenne pepper': 0.5178926441351889}, 6: {'chicken breasts': 0.7047713717693836, 'green onion': 0.55168986083499, 'red bell pepper': 0.6868787276341948, 'parsley': 0.47713717693836977, 'mayonnaise': 0.6610337972166999, 'sour cream': 0.5009940357852882, 'lemon juice': 0.514910536779324, 'dijon mustard': 0.6431411530815109, 'salt %26 pepper': 0.5695825049701789, 'cheddar cheese': 0.46322067594433397, 'potato chips': 0.6908548707753479}, 7: {'eggs': 0.514910536779324, 'milk': 0.4850894632206759, 'fresh sage': 0.0, 'fresh thyme': 0.7027833001988072, 'garlic cloves': 0.5805168986083499, 'pecorino cheese': 0.0, 'asparagus': 0.0, 'extra virgin olive oil': 0.562624254473161}, 8: {'butter': 0.39065606361829025, 'onion': 0.5785288270377733, 'garlic': 0.595427435387674, 'potatoes': 0.6540755467196819, 'flour': 0.529821073558648, 'milk': 0.4850894632206759, 'black pepper': 0.46421471172962225, 'nutmeg': 0.5447316103379721, 'creamed corn': 0.0, 'low sodium chicken broth': 0.7246520874751491, 'lump crabmeat': 0.0, 'cayenne pepper': 0.5178926441351889, 'parsley': 0.47713717693836977}, 9: {'lean ground beef': 0.0, 'ketchup': 0.7415506958250496, 'heinz chili sauce': 0.0, 'white vinegar': 0.7027833001988072, 'sugar': 0.45228628230616297, 'prepared yellow mustard': 0.0, 'onion powder': 0.6958250497017893}, 10: {'butter': 0.39065606361829025, 'granulated sugar': 0.7127236580516898, 'baking powder': 0.5944333996023857, 'salt': 0.35984095427435386, 'vanilla extract': 0.48210735586481107, 'eggs': 0.514910536779324, 'milk': 0.4850894632206759, 'whole wheat flour': 0.7823061630218687, 'chocolate chips': 0.5844930417495029, 'decorator sugar': 0.7823061630218687}, 11: {'all-purpose flour': 0.6809145129224652, 'baking soda': 0.6570576540755467, 'nutmeg': 0.5447316103379721, 'margarine': 0.6292246520874751, 'sugar': 0.45228628230616297, 'dark brown sugar': 0.8141153081510933, 'egg': 0.5218687872763419, 'egg white': 0.6590457256461232, 'vanilla': 0.46322067594433397, 'potato chips': 0.6908548707753479, 'semi-sweet chocolate chips': 0.5894632206759443}, 12: {'unsalted beef stock': 0.0, 'onion': 0.5785288270377733, 'carrot': 0.702783300198 ...

# %%
linked_list_data = dict()
for word in unique_words_all:
    linked_list_data[word] = SlinkedList()
    linked_list_data[word].head = Node(1,Node)
word_freq_in_doc = dict()
for idx, ingre_lst in enumerate(ingredients):
  words = []
  for ingre in ingre_lst:
    ingre = ingre[1:-1] # remove apostrophe
    ingre = remove_special_characters(ingre).lower()
    for word in ingre.split():
      words.append(word)
  word_freq_in_doc = find_words_freq(words)
  for word in word_freq_in_doc.keys():
      linked_list = linked_list_data[word].head
      while linked_list.nextval is not None:
          linked_list = linked_list.nextval
      linked_list.nextval = Node(idx ,word_freq_in_doc[word])

# %%
import time
query = input('Enter your query:')
query = word_tokenize(query)
connecting_words = []
cnt = 1
different_words = []
for word in query:
    if word.lower() != "and" and word.lower() != "or" and word.lower() != "not":
        different_words.append(word.lower())
    else:
        connecting_words.append(word.lower())
print(connecting_words)
total_dishes = len(ingredients)
zeroes_and_ones = []
zeroes_and_ones_of_all_words = []
for word in (different_words):
    if word.lower() in unique_words_all:
        zeroes_and_ones = [0] * total_dishes
        linkedlist = linked_list_data[word].head
        print(word)
        while linkedlist.nextval is not None:
            zeroes_and_ones[linkedlist.nextval.doc - 1] = 1
            linkedlist = linkedlist.nextval
        zeroes_and_ones_of_all_words.append(zeroes_and_ones)
    else:
        print(word," not found")
        sys.exit()
# print(zeroes_and_ones_of_all_words)
for word in connecting_words:
    word_list1 = zeroes_and_ones_of_all_words[0]
    word_list2 = zeroes_and_ones_of_all_words[1]
    if word == "and":
        bitwise_op = [w1 & w2 for (w1,w2) in zip(word_list1,word_list2)]
        zeroes_and_ones_of_all_words.remove(word_list1)
        zeroes_and_ones_of_all_words.remove(word_list2)
        zeroes_and_ones_of_all_words.insert(0, bitwise_op);
    elif word == "or":
        bitwise_op = [w1 | w2 for (w1,w2) in zip(word_list1,word_list2)]
        zeroes_and_ones_of_all_words.remove(word_list1)
        zeroes_and_ones_of_all_words.remove(word_list2)
        zeroes_and_ones_of_all_words.insert(0, bitwise_op);
    elif word == "not":
        bitwise_op = [not w1 for w1 in word_list2]
        bitwise_op = [int(b == True) for b in bitwise_op]
        zeroes_and_ones_of_all_words.remove(word_list2)
        zeroes_and_ones_of_all_words.remove(word_list1)
        bitwise_op = [w1 & w2 for (w1,w2) in zip(word_list1,bitwise_op)]
zeroes_and_ones_of_all_words.insert(0, bitwise_op);
 
# print(zeroes_and_ones_of_all_words)
lis = zeroes_and_ones_of_all_words[0]
output_dishes = []
for i in range(len(lis)):
  if lis[i] == 1:
    output_dishes.append(i)
end = time.time()
print('Runtime{: .4f}s'.format(end-start))
print(output_dishes)
# Out:
# Enter your query:rice and pork
# ['and']
# rice
# pork
# Runtime 57.3077s
# [291, 1603, 1769, 1942, 2265, 2267, 2344, 2498, 2552, 3194, 3390, 3737, 4095, 4693, 4936]

# %%
similarities = {}
for idx in output_dishes:
  dish_name = df2.iloc[idx]['name']
  print(dish_name)
  weight_vector = weight_vectors[idx]
  print(weight_vector)
  word1, word2 = different_words
  for key in weight_vector.keys():
    w1 = 0
    w2 = 0
    if word1 in key.split(): w1 = weight_vector.get(key, 0)
    if word2 in key.split(): w2 =  weight_vector.get(key, 0)
  print(w1,w2)
  for word in connecting_words:
    if word =='and':
      sim = 1- math.sqrt(((1-w1)**2 + (1-w2)**2))
    elif word == 'or':
      sim = math.sqrt(w1**2+w2**2)
    similarities[idx] = sim

print(similarities)
# Out:
# Sunflower Seed Brittle
# {'unsalted butter': 0.6043737574552683, 'dry roasted sunflower seeds': 0.0, 'salt': 0.35984095427435386, 'sugar': 0.45228628230616297}
# 0 0
# Waffles With Cinnamon Fruit Sauce
# {'frozen buttermilk waffles': 0.0, 'pineapple tidbits': 0.0, 'maraschino cherry': 0.7246520874751491, 'orange juice': 0.6620278330019881, 'powdered sugar': 0.510934393638171, 'cornstarch': 0.6023856858846918, 'cinnamon': 0.49204771371769385, 'mandarin oranges': 0.8141153081510933}
# 0 0
# Sausage-Stuffed Zucchini
# {'zucchini': 0.6640159045725645, 'italian sausage': 0.0, 'yellow onion': 0.8409542743538768, 'fresh parsley': 0.4741550695825049, 'fresh basil': 0.5427435387673956, 'dried marjoram': 0.0, 'fine dry breadcrumb': 0.7713717693836978, 'parmesan cheese': 0.37176938369781315, 'salt': 0.35984095427435386, 'black pepper': 0.46421471172962225, 'egg': 0.5218687872763419}
# 0 0
# Shrewsbury Cakes
# {'butter': 0.39065606361829025, 'sugar': 0.45228628230616297, 'vanilla': 0.46322067594433397, 'salt': 0.35984095427435386, 'egg': 0.5218687872763419, 'flour': 0.529821073558648, 'citron': 0.8757455268389662}
# 0 0
# Haggis Loaf
# {'boneless lamb shoulder': 0.0, 'lamb liver': 0.0, 'water': 0.3846918489065606, 'onion': 0.5785288270377733, 'egg': 0.5218687872763419, 'salt': 0.35984095427435386, 'black pepper': 0.46421471172962225, 'sugar': 0.45228628230616297, 'ground ginger': 0.668986083499006, 'ground cloves': 0.6530815109343936, 'ground nutmeg': 0.647117296222664, 'pinhead oats': 0.8220675944333995}
# 0 0
# Swedish &quot;meat&quot; Balls With Gravy (Vegan)
# {'breadcrumbs': 0.6401590457256461, 'plain soymilk': 0.0, 'vegetable broth': 0.0, 'textured vegetable protein': 0.0, 'onion': 0.5785288270377733, 'dried parsley flakes': 0.8001988071570577, 'garlic powder': 0.5387673956262425, 'nutmeg': 0.5447316103379721, 'sea salt': 0.6749502982107356, 'black pepper': 0.46421471172962225, 'canola oil': 0.5636182902584492, 'button mushrooms': 0.0, 'coffee creamer': 0.0, 'cornstarch': 0.6023856858846918, 'nutritional yeast': 0.8508946322067594, 'braggs liquid aminos': 0.794234592445328}
# 0 0
# Mushroom Bacon Pie
# {'mushroom': 0.7664015904572564, 'bacon': 0.6172962226640158, 'garlic': 0.595427435387674, 'fresh parsley': 0.4741550695825049, 'olive oil': 0.4433399602385686, 'eggs': 0.514910536779324, 'parmesan cheese': 0.37176938369781315, 'salt': 0.35984095427435386, 'black pepper': 0.46421471172962225, '9%22 unbaked pie shell': 0.8409542743538768}
# 0 0
# Veggie Crumble Tacos
# {'veggie crumbles': 0.0, 'oil': 0.48011928429423456, 'taco seasoning mix': 0.0, 'water': 0.3846918489065606, 'tomatoes': 0.5934393638170974, 'green onion': 0.55168986083499, 'green leaf lettuce': 0.0, 'low-fat cheddar cheese': 0.8628230616302186, 'salsa': 0.5715705765407555, 'taco shells': 0.8409542743538768}
# 0 0
# French Spaghetti
# {'spaghetti': 0.8220675944333995, 'green peppers': 0.831013916500994, 'onion': 0.5785288270377733, 'butter': 0.39065606361829025, 'diced tomatoes': 0.6978131212723657, 'sliced mushrooms': 0.0, 'pitted ripe olives': 0.0, 'all-purpose flour': 0.6809145129224652, 'salt': 0.35984095427435386, 'whipping cream': 0.5894632206759443, 'milk': 0.4850894632206759, 'parmesan cheese': 0.37176938369781315}
# 0 0
# Greeny's Quick and Easy Thai-Ish Ramen Noodle Bowl
# {'ramen noodles': 0.0, 'peanut butter': 0.6848906560636182, 'low sodium soy sauce': 0.8508946322067594, 'chili-garlic sauce': 0.0, 'hot water': 0.6620278330019881, 'sweetened flaked coconut': 0.0, 'broccoli floret': 0.0, 'peanuts': 0.5815109343936381, 'carrot': 0.7027833001988072}
# 0 0
# Feta, Spinach and Sweet Potato Wrap
